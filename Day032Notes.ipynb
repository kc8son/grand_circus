# %% [markdown]
# ### Links...
# - https://seaborn.pydata.org/
# - colab.research.google.com/drive/11JFiln5P5npKPL8xYLNDFRDQcUV5U3TE
# -- see how o use a complex foemula for .fillna()
# - feature/column/atttribute - all the same
# - kaggle kanncaa1/time-series-prediction-tutorial
# - Jason's notebook: https://colab.research.google.com/drive/11JFiln5P5npKPL8xYLNDFRDQcUV5U3TE#scrollTo=_bXtRAo-3y6k
# - Nirmala's kaggle competition:  https://www.kaggle.com/competitions/google-research-identify-contrails-reduce-global-warming
# - research treemap
# - research sns.pairplot

# %%
import pandas as pd
import numpy as np
import seaborn as sns


df = pd.read_csv(
    'https://exeter-qstep-resources.github.io/pokemon_dataset.csv',
    index_col=0,
    encoding='ISO-8859-1'
    )

# %%
df.shape
# Out:
# (151, 12)

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
df['Type 1'].value_counts(dropna=False)
# Out:
# Water       28
# Normal      22
# Poison      14
# Grass       12
# Fire        12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Ghost        3
# Dragon       3
# Fairy        2
# Ice          2
# Name: Type 1, dtype: int64

# %%
# Question: 
sns.boxplot(data=df, x="Attack", y="Type 1")
# Out:
# <Axes: xlabel='Attack', ylabel='Type 1'>

# %%
# Question: 
sns.boxplot(data=df, x="Attack", y="Type 2")
# Out:
# <Axes: xlabel='Attack', ylabel='Type 2'>

# %%
# This doesn't work because of the legendary column.  It doesn't seem to like booleans
# sns.pairplot(df[['']], hue="Type 1" )
# "Name", "Type 1", "Type 2", "Total", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed", "Stage"
sns.pairplot(df[["Name", "Type 1", "Type 2", "Total", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed", "Stage"]], hue="Type 1" )
How does it

# %% [markdown]
# ### Single bracket is a series, double bracket is a dataframe...

# %%
# print(df['Name'])
print(type(df['Name']))
print(type(df[['Name']]))
# single bracket is a series, double bracket is a dataframe...
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df.isnull().sum() / len(df)
# Out:
# Name         0.000000
# Type 1       0.000000
# Type 2       0.556291
# Total        0.000000
# HP           0.000000
# Attack       0.000000
# Defense      0.000000
# Sp. Atk      0.000000
# Sp. Def      0.000000
# Speed        0.000000
# Stage        0.000000
# Legendary    0.000000
# dtype: float64

# %%
df['Type 2'].value_counts(0, dropna=False)
# Out:
# NaN         84
# Poison      19
# Flying      19
# Ground       6
# Psychic      6
# Water        4
# Fairy        3
# Ice          3
# Grass        2
# Steel        2
# Rock         2
# Fighting     1
# Name: Type 2, dtype: int64

# %%
flight = sns.load_dataset("flights")

# %%
tips = sns.load_dataset("tips")

# %%
tips.corr()
# Out:
# C:\Users\j\AppData\Local\Temp\ipykernel_15916\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap="coolwarm", annot=True)
# Out:
# C:\Users\j\AppData\Local\Temp\ipykernel_15916\1996064626.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), cmap="coolwarm", annot=True)
# <Axes: >

# %%
# flight.pivot_table(values="pasengers", index="mpnth", columns="
flight.pivot_table(values="passengers", index="month", columns="year")
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pd.crosstab(flight["month"], flight["year"], flight["passengers"], aggfunc="sum")
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
pvt_flights = pd.crosstab(flight["month"], flight["year"], flight["passengers"], aggfunc="sum")
pvt_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.clustermap(pvt_flights)
