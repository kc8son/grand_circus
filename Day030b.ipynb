# %% [markdown]
# # Day030 - Joseph P. Merten
# ## Data Analytics 2: Data Visualization & Predictions - Flying Etiquette Survey (Data Visualization) - Due May 8
# - Following along with this video: https://www.youtube.com/watch?v=xi0vhXFPegw

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')    #    Set style sheet
pd.set_option('display.max_columns', 300)    #    Set the number of columns displayed

# %% [markdown]
# ### Go get data...

# %%
#data_url = r'https://raw.githubusercontent.com/fivethirtyeight/data/master/flying-etiquette-survey/flying-etiquette.csv'
data_url = r'C:\Users\j\Documents\code\GrandCircus\Day030\coaster_db.csv'
# print(data_url)
coaster_df = pd.read_csv(data_url)

# %% [markdown]
# ### Step 1 - Data exploration

# %%
coaster_df.shape
# Out:
# (1087, 56)

# %%
coaster_df.head(20)
# Out:
#                               coaster_name              Length  \
# 0                       Switchback Railway      600 ft (180 m)
# 1                        Flip Flap Railway                 NaN
# 2   Switchback Railway (Euclid Beach Park)                 NaN
# 3             Loop the Loop (Coney Island)                 NaN
# 4             Loop the Loop (Young's Pier)                 NaN
# 5                           Cannon Coaster                 NaN
# 6                            Leap-The-Dips    1,452 ft (443 m)
# 7         Figure Eight (Euclid Beach Park)                 NaN
# 8                             Drop the Dip                 NaN
# 9       Scenic Railway (Euclid Beach Park)                 NaN
# 10          Loop the Loop (Olentangy Park)                 NaN
# 11                               Aero Dips                 NaN
# 12             Backety-Back Scenic Railway                 NaN
# 13             Racer (1910 roller coaster)  4,500 ft (1,400 m)
# ...

# %%
coaster_df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
coaster_df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
coaster_df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### Step 2 - Data Preparation.
# - Drop irrelevant columns & row
# - Identifying dduplicate columns
# - Renaming columns
# - Feature creation

# %%
# Get a subsey of the data
coaster_df[['coaster_name', 'year_introduced', 'latitude', 'longitude', 'Type_Main', 'Location', 'Status', 
            'opening_date_clean', 'speed_mph', 'Inversions_clean', 'Gforce_clean']]
# Out:
#                                 coaster_name  year_introduced  latitude  \
# 0                         Switchback Railway             1884   40.5740
# 1                          Flip Flap Railway             1895   40.5780
# 2     Switchback Railway (Euclid Beach Park)             1896   41.5800
# 3               Loop the Loop (Coney Island)             1901   40.5745
# 4               Loop the Loop (Young's Pier)             1901   39.3538
# ...                                      ...              ...       ...
# 1082                 American Dreier Looping             2022       NaN
# 1083               Pantheon (roller coaster)             2022   37.2339
# 1084               Tron Lightcycle Power Run             2022       NaN
# 1085                                 Tumbili             2022       NaN
# 1086          Wonder Woman Flight of Courage             2022       NaN
#
#       longitude Type_Main                        Location              Status  \
# ...

# %%
#    We need to sepcify axis=1 to drop a column instead of a row.  
#    Also need to enclose the column name in square nracket to drop the column.
coaster_df.drop(['Opening date'], axis=1)
coaster_df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# reassign to the subsetted data fraom...  Notice the double square brackets.  
# Also note the .c9py() wich tells python this is a new dataframe and NOT a reference to the old one.
coaster_df = coaster_df[['coaster_name', 'Location', 'Status', 'year_introduced', 'latitude', 'longitude', 'Type_Main', 
            'opening_date_clean', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
coaster_df.shape
# Out:
# (1087, 12)
